# %% [markdown]
# #### Cheat sheets:
#
# https://s3.amazonaws.com/assets.datacamp.com/email/other/ML+Cheat+Sheet_2.pdf
#
# https://www.datacamp.com/cheat-sheet/machine-learning-cheat-sheet
#
# #### Course:
# https://rakuten.udemy.com/course/python-for-machine-learning-data-science-masterclass/learn/lecture/22992400?learning_path_id=3236876#overview

# %%
# !pip install jupyter_contrib_nbextensions
# !pip3 install jupyter_contrib_nbextensions
# !jupyter contrib nbextension install --user
# !pip install jupyter_nbextensions_configurator
# !pip3 install jupyter_nbextensions_configurator
# !jupyter nbextensions_configurator enable --user

# http://localhost:8888/nbextensions/
# Out:
# Requirement already satisfied: jupyter_contrib_nbextensions in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (0.5.1)
# Requirement already satisfied: tornado in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (6.2)
# Requirement already satisfied: jupyter-latex-envs>=1.3.8 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (1.4.6)
# Requirement already satisfied: pyyaml in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (6.0)
# Requirement already satisfied: jupyter-core in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (4.11.2)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.4.0)
# Requirement already satisfied: ipython-genutils in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: notebook>=4.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (6.5.1)
# Requirement already satisfied: traitlets>=4.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (5.5.0)
# Requirement already satisfied: nbconvert>=4.2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (7.2.2)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: lxml in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (4.9.1)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.5.0)
# Requirement already satisfied: ipython in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (8.5.0)
# Requirement already satisfied: setuptools in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (41.2.0)
# Requirement already satisfied: jinja2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: nbformat in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (5.7.0)
# Requirement already satisfied: argon2-cffi in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.16.0)
# Requirement already satisfied: prometheus-client in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.15.0)
# Requirement already satisfied: nbclassic==0.4.5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.4.5)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (1.5.6)
# Requirement already satisfied: pyzmq>=17 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (24.0.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (7.4.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: ipykernel in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (6.16.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: importlib-metadata>=3.6; python_version < "3.10" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (4.12.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: bleach in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (5.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: defusedxml in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (4.11.1)
# Requirement already satisfied: packaging in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (21.3)
# Requirement already satisfied: pygments>=2.4.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.13.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.1.1)
# Requirement already satisfied: tinycss2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: stack-data in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: matplotlib-inline in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (3.0.31)
# Requirement already satisfied: backcall in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: decorator in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.1.3)
# Requirement already satisfied: fastjsonschema in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (4.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from terminado>=0.8.3->notebook>=4.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbclassic==0.4.5->notebook>=4.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbclassic==0.4.5->notebook>=4.0->jupyter_contrib_nbextensions) (1.21.0)
# Requirement already satisfied: entrypoints in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook>=4.0->jupyter_contrib_nbextensions) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook>=4.0->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: debugpy>=1.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (1.6.3)
# Requirement already satisfied: psutil in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (5.9.3)
# Requirement already satisfied: zipp>=0.5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from importlib-metadata>=3.6; python_version < "3.10"->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.8.1)
# Requirement already satisfied: six>=1.9.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from beautifulsoup4->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.3.2.post1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from packaging->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.0.9)
# Requirement already satisfied: executing in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from stack-data->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (1.1.1)
# Requirement already satisfied: asttokens in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from stack-data->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (2.0.8)
# Requirement already satisfied: pure-eval in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from stack-data->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: wcwidth in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jedi>=0.16->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (22.1.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (5.10.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (1.15.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.0->jupyter_contrib_nbextensions) (3.6.2)
# Requirement already satisfied: websocket-client in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.0->jupyter_contrib_nbextensions) (1.4.1)
# Requirement already satisfied: pycparser in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: sniffio>=1.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.0->jupyter_contrib_nbextensions) (3.4)
# WARNING: You are using pip version 19.2.3, however version 22.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: jupyter_contrib_nbextensions in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (0.5.1)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.5.0)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.4.0)
# Requirement already satisfied: jupyter-core in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (4.11.2)
# Requirement already satisfied: lxml in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (4.9.1)
# Requirement already satisfied: notebook>=4.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (6.5.1)
# Requirement already satisfied: pyyaml in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (6.0)
# Requirement already satisfied: ipython-genutils in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: nbconvert>=4.2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (7.2.2)
# Requirement already satisfied: jupyter-latex-envs>=1.3.8 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (1.4.6)
# Requirement already satisfied: traitlets>=4.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (5.5.0)
# Requirement already satisfied: tornado in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (6.2)
# Requirement already satisfied: setuptools in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (41.2.0)
# Requirement already satisfied: pyzmq>=17 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (24.0.1)
# Requirement already satisfied: jinja2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: prometheus-client in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.15.0)
# Requirement already satisfied: argon2-cffi in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (7.4.3)
# Requirement already satisfied: ipykernel in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (6.16.1)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (1.5.6)
# Requirement already satisfied: nbclassic==0.4.5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.4.5)
# Requirement already satisfied: nbformat in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (5.7.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.16.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: pygments>=2.4.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.13.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: bleach in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (5.0.1)
# Requirement already satisfied: defusedxml in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: importlib-metadata>=3.6; python_version < "3.10" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (4.12.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: packaging in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (21.3)
# Requirement already satisfied: tinycss2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: markupsafe>=2.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.1.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: beautifulsoup4 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (4.11.1)
# Requirement already satisfied: ipython in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (8.5.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook>=4.0->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: entrypoints in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook>=4.0->jupyter_contrib_nbextensions) (0.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: psutil in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (5.9.3)
# Requirement already satisfied: debugpy>=1.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (1.6.3)
# Requirement already satisfied: appnope; platform_system == "Darwin" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (0.1.3)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbclassic==0.4.5->notebook>=4.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbclassic==0.4.5->notebook>=4.0->jupyter_contrib_nbextensions) (1.21.0)
# Requirement already satisfied: fastjsonschema in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (4.16.0)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from terminado>=0.8.3->notebook>=4.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: webencodings in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from importlib-metadata>=3.6; python_version < "3.10"->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from packaging->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.0.9)
# Requirement already satisfied: soupsieve>1.2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from beautifulsoup4->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.3.2.post1)
# Requirement already satisfied: jedi>=0.16 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (3.0.31)
# Requirement already satisfied: stack-data in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: decorator in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: backcall in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (1.15.1)
# Requirement already satisfied: websocket-client in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.0->jupyter_contrib_nbextensions) (1.4.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.0->jupyter_contrib_nbextensions) (3.6.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (22.1.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (5.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jedi>=0.16->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: executing in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from stack-data->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (1.1.1)
# Requirement already satisfied: pure-eval in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from stack-data->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: asttokens in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from stack-data->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (2.0.8)
# Requirement already satisfied: pycparser in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: idna>=2.8 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.0->jupyter_contrib_nbextensions) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.0->jupyter_contrib_nbextensions) (1.3.0)
# WARNING: You are using pip version 19.2.3, however version 22.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# [I 15:28:02 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 15:28:02 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband -> rubberband
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/rubberband/icon.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/rubberband/main.css
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/rubberband/readme.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/rubberband/main.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/rubberband/rubberband.yaml
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/scroll_down -> scroll_down
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/scroll_down/icon.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/scroll_down/config.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/scroll_down/readme.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/scroll_down/main.js
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/hinterland -> hinterland
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/hinterland/hinterland.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/hinterland/hinterland.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/hinterland/README.md
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/snippets -> snippets
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/snippets/snippets.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/snippets/snippets.json
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/snippets/README.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/snippets/main.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/snippets/snippets-demo.gif
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/toggle_all_line_numbers -> toggle_all_line_numbers
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toggle_all_line_numbers/icon.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toggle_all_line_numbers/main.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toggle_all_line_numbers/readme.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toggle_all_line_numbers/main.js
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/notify -> notify
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/notify/notify.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/notify/notify.mp3
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/notify/readme.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/notify/notify.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/notify/notification.png
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/runtools -> runtools
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/cellstate.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/icon.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/runtools_execute.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/annotations.odg
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/runtools.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/main.css
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/runtools_nb.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/readme.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/runtools_marker.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/main.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/runtools_show_hide.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/runtools_lock.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/demo.gif
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/runtools/gutter.css
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/tree-filter -> tree-filter
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/tree-filter/tree-filter.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/tree-filter/index.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/tree-filter/readme.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/tree-filter/demo.gif
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/table_beautifier -> table_beautifier
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/table_beautifier/main.css
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/table_beautifier/README.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/table_beautifier/main.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/table_beautifier/table_beautifier.yaml
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/freeze -> freeze
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/freeze/icon.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/freeze/config.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/freeze/readme.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/freeze/main.js
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise2 -> exercise2
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/exercise2/icon.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/exercise2/exercise2.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/exercise2/main.css
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/exercise2/image.gif
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/exercise2/readme.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/exercise2/main.js
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/execution_dependencies -> execution_dependencies
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/execution_dependencies/execution_dependencies.yml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/execution_dependencies/README.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/execution_dependencies/execution_dependencies.js
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/skill -> skill
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/skill/skill.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/skill/README.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/skill/main.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/skill/skill.yaml
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/splitcell -> splitcell
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/splitcell/icon.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/splitcell/readme.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/splitcell/splitcell.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/splitcell/splitcell.js
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/autosavetime -> autosavetime
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/autosavetime/icon.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/autosavetime/README.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/autosavetime/autosavetime.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/autosavetime/main.js
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap -> select_keymap
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/select_keymap/select_keymap.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/select_keymap/README.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/select_keymap/main.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/select_keymap/select_keymap.yaml
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/livemdpreview -> livemdpreview
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/livemdpreview/livemdpreview.yml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/livemdpreview/livemdpreview.js
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/gist_it -> gist_it
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/gist_it/icon.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/gist_it/gist_it.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/gist_it/readme.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/gist_it/main.js
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/cell_filter -> cell_filter
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/cell_filter/cell_filter.yml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/cell_filter/cell_filter.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/cell_filter/README.md
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad -> scratchpad
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/scratchpad/LICENSE
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/scratchpad/scratchpad.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/scratchpad/README.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/scratchpad/main.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/scratchpad/scratchpad.css
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/scratchpad/demo.gif
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/toc2 -> toc2
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toc2/toc2.yaml
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toc2/icon.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toc2/demo_dark.png
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toc2/main.css
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toc2/README.md
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toc2/main.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toc2/demo3.gif
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toc2/demo2.gif
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toc2/toc2.js
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toc2/demo.gif
# [I 15:28:02 InstallContribNbextensionsApp] Up to date: /Users/sreedhar.k/Library/Jupyter/nbextensions/toc2/image.png
# [I 15:28:02 InstallContribNbextensionsApp] - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] Installing /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate -> nbTranslate
# ...
#     - Validating...
#       jupyter_nbextensions_configurator 0.4.1 OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...
# [I 15:28:02 InstallContribNbextensionsApp] Enabling notebook extension contrib_nbextensions_help_item/main...
# [I 15:28:02 InstallContribNbextensionsApp]       - Validating: OK
# [I 15:28:02 InstallContribNbextensionsApp] - Editing config: /Users/sreedhar.k/.jupyter/jupyter_nbconvert_config.json
# [I 15:28:02 InstallContribNbextensionsApp] --  Configuring nbconvert template path
# [I 15:28:02 InstallContribNbextensionsApp] --  Configuring nbconvert preprocessors
# [I 15:28:02 InstallContribNbextensionsApp] - Writing config: /Users/sreedhar.k/.jupyter/jupyter_nbconvert_config.json
# [I 15:28:02 InstallContribNbextensionsApp] --  Writing updated config file /Users/sreedhar.k/.jupyter/jupyter_nbconvert_config.json
# Requirement already satisfied: jupyter_nbextensions_configurator in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (0.5.0)
# Requirement already satisfied: pyyaml in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_nbextensions_configurator) (6.0)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_nbextensions_configurator) (0.4.0)
# Requirement already satisfied: traitlets in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_nbextensions_configurator) (5.5.0)
# Requirement already satisfied: notebook>=6.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_nbextensions_configurator) (6.5.1)
# Requirement already satisfied: jupyter-core in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_nbextensions_configurator) (4.11.2)
# Requirement already satisfied: tornado in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter_nbextensions_configurator) (6.2)
# Requirement already satisfied: setuptools in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_nbextensions_configurator) (41.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (1.5.6)
# Requirement already satisfied: terminado>=0.8.3 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (0.16.0)
# Requirement already satisfied: nbclassic==0.4.5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (0.4.5)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (7.4.3)
# Requirement already satisfied: nbformat in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (5.7.0)
# Requirement already satisfied: ipykernel in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (6.16.1)
# Requirement already satisfied: argon2-cffi in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (21.3.0)
# Requirement already satisfied: prometheus-client in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (0.15.0)
# Requirement already satisfied: pyzmq>=17 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (24.0.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (1.8.0)
# Requirement already satisfied: ipython-genutils in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (0.2.0)
# Requirement already satisfied: nbconvert>=5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (7.2.2)
# Requirement already satisfied: jinja2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from notebook>=6.0->jupyter_nbextensions_configurator) (3.1.2)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from terminado>=0.8.3->notebook>=6.0->jupyter_nbextensions_configurator) (0.7.0)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbclassic==0.4.5->notebook>=6.0->jupyter_nbextensions_configurator) (1.21.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbclassic==0.4.5->notebook>=6.0->jupyter_nbextensions_configurator) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook>=6.0->jupyter_nbextensions_configurator) (2.8.2)
# Requirement already satisfied: entrypoints in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook>=6.0->jupyter_nbextensions_configurator) (0.4)
# Requirement already satisfied: jsonschema>=2.6 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbformat->notebook>=6.0->jupyter_nbextensions_configurator) (4.16.0)
# Requirement already satisfied: fastjsonschema in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbformat->notebook>=6.0->jupyter_nbextensions_configurator) (2.16.2)
# Requirement already satisfied: ipython>=7.23.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (8.5.0)
# Requirement already satisfied: appnope; platform_system == "Darwin" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (0.1.3)
# Requirement already satisfied: debugpy>=1.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (1.6.3)
# Requirement already satisfied: psutil in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (5.9.3)
# Requirement already satisfied: packaging in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (21.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (0.1.6)
# Requirement already satisfied: argon2-cffi-bindings in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from argon2-cffi->notebook>=6.0->jupyter_nbextensions_configurator) (21.2.0)
# Requirement already satisfied: defusedxml in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (1.5.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (2.0.4)
# Requirement already satisfied: pygments>=2.4.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (2.13.0)
# Requirement already satisfied: tinycss2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (2.1.1)
# Requirement already satisfied: beautifulsoup4 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (4.11.1)
# Requirement already satisfied: bleach in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (5.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (0.7.0)
# Requirement already satisfied: importlib-metadata>=3.6; python_version < "3.10" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (4.12.0)
# Requirement already satisfied: websocket-client in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic==0.4.5->notebook>=6.0->jupyter_nbextensions_configurator) (1.4.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic==0.4.5->notebook>=6.0->jupyter_nbextensions_configurator) (3.6.2)
# Requirement already satisfied: six>=1.5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->notebook>=6.0->jupyter_nbextensions_configurator) (1.16.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=6.0->jupyter_nbextensions_configurator) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=6.0->jupyter_nbextensions_configurator) (5.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=6.0->jupyter_nbextensions_configurator) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=6.0->jupyter_nbextensions_configurator) (22.1.0)
# Requirement already satisfied: pickleshare in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (0.7.5)
# Requirement already satisfied: decorator in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (5.1.1)
# Requirement already satisfied: stack-data in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (0.5.1)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (4.8.0)
# Requirement already satisfied: backcall in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (3.0.31)
# Requirement already satisfied: jedi>=0.16 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (0.18.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from packaging->ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (3.0.9)
# Requirement already satisfied: cffi>=1.0.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_nbextensions_configurator) (1.15.1)
# Requirement already satisfied: webencodings>=0.4 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from tinycss2->nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (0.5.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (2.3.2.post1)
# Requirement already satisfied: zipp>=0.5 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from importlib-metadata>=3.6; python_version < "3.10"->nbconvert>=5->notebook>=6.0->jupyter_nbextensions_configurator) (3.8.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic==0.4.5->notebook>=6.0->jupyter_nbextensions_configurator) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic==0.4.5->notebook>=6.0->jupyter_nbextensions_configurator) (3.4)
# Requirement already satisfied: executing in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (1.1.1)
# Requirement already satisfied: asttokens in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (2.0.8)
# Requirement already satisfied: pure-eval in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (0.2.2)
# Requirement already satisfied: wcwidth in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_nbextensions_configurator) (0.8.3)
# Requirement already satisfied: pycparser in /Users/sreedhar.k/.pyenv/versions/3.8.0/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_nbextensions_configurator) (2.21)
# WARNING: You are using pip version 19.2.3, however version 22.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Enabling: jupyter_nbextensions_configurator
# - Writing config: /Users/sreedhar.k/.jupyter
#     - Validating...
#       jupyter_nbextensions_configurator 0.4.1 OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...

# %%
from IPython.display import HTML
from ipynb.fs.defs._2_Pandas import hide_toggle

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
