# %% [markdown]
# - Deep Learning A-Z™: Download Practice Datasets and code:
#   -  https://www.tfcertification.com/pages/deep-learning
#
# - Deep learning diagram
#    - <img src="data:image/jpeg;base64,..." height="800" width="800">
